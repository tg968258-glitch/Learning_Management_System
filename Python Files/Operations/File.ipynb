# %%
import pandas as pd
df=pd.read_csv('MOCK_DATA.csv')
print(df)
# Out:
#        id first_name last_name                    email      gender
# 0       1        Arv   McArdle   amcardle0@google.co.uk        Male
# 1       2     Verena   Mandres     vmandres1@scribd.com      Female
# 2       3      Emera    Latour       elatour2@jimdo.com      Female
# 3       4      Tessi   Affleck       taffleck3@about.me      Female
# 4       5    Joseito    Brason  jbrason4@shutterfly.com        Male
# ..    ...        ...       ...                      ...         ...
# 995   996      Paige   Wayland      pwaylandrn@tamu.edu      Female
# 996   997  Dominique  Claussen  dclaussenro@state.tx.us        Male
# 997   998     Nollie     Aseef        naseefrp@bing.com  Polygender
# 998   999     Lulita   Marquez  lmarquezrq@google.co.uk      Female
# 999  1000    Rachele  McComish  rmccomishrr@weather.com      Female
#
# [1000 rows x 5 columns]

# %%
print(df.head())
# Out:
#    id first_name last_name                    email  gender
# 0   1        Arv   McArdle   amcardle0@google.co.uk    Male
# 1   2     Verena   Mandres     vmandres1@scribd.com  Female
# 2   3      Emera    Latour       elatour2@jimdo.com  Female
# 3   4      Tessi   Affleck       taffleck3@about.me  Female
# 4   5    Joseito    Brason  jbrason4@shutterfly.com    Male

# %%
print(df[["first_name", "email"]])
# Out:
#     first_name                    email
# 0          Arv   amcardle0@google.co.uk
# 1       Verena     vmandres1@scribd.com
# 2        Emera       elatour2@jimdo.com
# 3        Tessi       taffleck3@about.me
# 4      Joseito  jbrason4@shutterfly.com
# ..         ...                      ...
# 995      Paige      pwaylandrn@tamu.edu
# 996  Dominique  dclaussenro@state.tx.us
# 997     Nollie        naseefrp@bing.com
# 998     Lulita  lmarquezrq@google.co.uk
# 999    Rachele  rmccomishrr@weather.com
#
# [1000 rows x 2 columns]

# %%
print(df[10:20])
# Out:
#     id first_name  last_name                      email      gender
# 10  11      Rufus     Fanton      rfantona@sakura.ne.jp        Male
# 11  12        Cal   Doddrell  cdoddrellb@mayoclinic.com      Female
# 12  13     Vernor  MacGuffog         vmacguffogc@goo.gl        Male
# 13  14      Karly    Francke        kfrancked@hc360.com    Bigender
# 14  15     Kipper   Custance  kcustancee@wikispaces.com        Male
# 15  16       Ewan  Le feaver    elefeaverf@cbslocal.com  Non-binary
# 16  17     Gideon    Wingham       gwinghamg@census.gov        Male
# 17  18      Major     Ginity           mginityh@mtv.com        Male
# 18  19     Helena   Heintsch      hheintschi@spiegel.de      Female
# 19  20     Kenyon    Jarmain    kjarmainj@cafepress.com        Male

# %%
result=df[df['first_name'].str.startswith("A")]
print(result)
# Out:
#       id first_name  last_name                       email  gender
# 0      1        Arv    McArdle      amcardle0@google.co.uk    Male
# 7      8       Agna    Hritzko       ahritzko7@dropbox.com  Female
# 21    22       Aube  O'Leagham      aoleaghaml@alibaba.com    Male
# 26    27     Abramo   Cardenas   acardenasq@altervista.org    Male
# 28    29   Annabela  Swadlinge   aswadlinges@earthlink.net  Female
# ..   ...        ...        ...                         ...     ...
# 954  955   Annalise      Sandy        asandyqi@example.com  Female
# 966  967     Almire      Ewens        aewensqu@dropbox.com  Female
# 971  972    Ambrose       Reef           areefqz@weibo.com    Male
# 975  976     Almire   Pallasch  apallaschr3@infoseek.co.jp  Female
# 990  991     Austin     Thrift   athriftri@miibeian.gov.cn  Female
#
# [84 rows x 5 columns]
