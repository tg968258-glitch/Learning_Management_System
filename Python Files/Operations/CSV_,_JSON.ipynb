# %%
import pandas as pd
df=pd.read_csv("/content/healthexp.csv")
print(df)
df.head()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# ...

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
import csv
with open("/content/healthexp.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Year', 'Country', 'Spending_USD', 'Life_Expectancy']
# ['1970', 'Germany', '252.311', '70.6']
# ['1970', 'France', '192.143', '72.2']
# ['1970', 'Great Britain', '123.993', '71.9']
# ['1970', 'Japan', '150.437', '72.0']
# ['1970', 'USA', '326.961', '70.9']
# ['1971', 'Canada', '313.391', '72.8']
# ['1971', 'Germany', '298.251', '70.8']
# ['1971', 'Great Britain', '134.172', '71.9']
# ['1971', 'Japan', '163.854', '72.9']
# ['1971', 'USA', '357.988', '71.2']
# ['1972', 'Germany', '337.364', '71.0']
# ['1972', 'Japan', '185.39', '73.2']
# ['1972', 'USA', '397.097', '71.2']
# ['1973', 'Germany', '384.541', '71.3']
# ['1973', 'Japan', '205.778', '73.4']
# ['1973', 'USA', '439.302', '71.4']
# ['1974', 'Germany', '452.744', '71.5']
# ['1974', 'Japan', '242.018', '73.7']
# ['1974', 'USA', '495.114', '72.0']
# ['1975', 'Germany', '532.481', '71.4']
# ['1975', 'France', '363.61', '73.0']
# ['1975', 'Japan', '284.269', '74.3']
# ['1975', 'USA', '560.75', '72.7']
# ...

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'student-data.json', 'sample_data']

# %%
with open("/content/student-data.json", "r") as file:
    text = file.read()

print(repr(text))
# Out:
# "[  \n   {  \n      name:'arun',\n      gender:'Male',\n      physics:88,\n      maths:87,\n      english:78\n   },\n   {  \n      name:'rajesh',\n      gender:'Male',\n      physics:96,\n      maths:100,\n      english:95\n   },\n   {  \n      name:'moorthy',\n      gender:'Male',\n      physics:89,\n      maths:90,\n      english:70\n   },\n   {  \n      name:'raja',\n      gender:'Male',\n      physics:30,\n      maths:25,\n      english:40\n   },\n   {  \n      name:'usha',\n      gender:'Female',\n      physics:67,\n      maths:45,\n      english:78\n   },\n   {  \n      name:'priya',\n      gender:'Female',\n      physics:56,\n      maths:46,\n      english:78\n   },\n   {  \n      name:'Sundar',\n      gender:'Male',\n      physics:12,\n      maths:67,\n      english:67\n   },\n   {  \n      name:'Kavitha',\n      gender:'Female',\n      physics:78,\n      maths:71,\n      english:67\n   },\n   {  \n      name:'Dinesh',\n      gender:'Male',\n      physics:56,\n      maths:45,
# ...

# %%
import json

with open("/content/sample1.json", "r") as file:
    data = json.load(file)

print(data)
# Out:
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2706/4192169265.py in <cell line: 0>()
#       6 print(data)
#       7
# ----> 8 json.parse(sample1)
#
# AttributeError: module 'json' has no attribute 'parse'

# %%
json.parse(sample1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2706/238280733.py in <cell line: 0>()
# ----> 1 json.parse(sample1)
#
# AttributeError: module 'json' has no attribute 'parse'

# %%
import csv

with open("healthexp.csv", "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        try:
            year = int(row["Year"])
            print(row)

        except ValueError:
            print("Invalid numeric value:", row)
# Out:
# {'Year': '1970', 'Country': 'Germany', 'Spending_USD': '252.311', 'Life_Expectancy': '70.6'}
# {'Year': '1970', 'Country': 'France', 'Spending_USD': '192.143', 'Life_Expectancy': '72.2'}
# {'Year': '1970', 'Country': 'Great Britain', 'Spending_USD': '123.993', 'Life_Expectancy': '71.9'}
# {'Year': '1970', 'Country': 'Japan', 'Spending_USD': '150.437', 'Life_Expectancy': '72.0'}
# {'Year': '1970', 'Country': 'USA', 'Spending_USD': '326.961', 'Life_Expectancy': '70.9'}
# {'Year': '1971', 'Country': 'Canada', 'Spending_USD': '313.391', 'Life_Expectancy': '72.8'}
# {'Year': '1971', 'Country': 'Germany', 'Spending_USD': '298.251', 'Life_Expectancy': '70.8'}
# {'Year': '1971', 'Country': 'Great Britain', 'Spending_USD': '134.172', 'Life_Expectancy': '71.9'}
# {'Year': '1971', 'Country': 'Japan', 'Spending_USD': '163.854', 'Life_Expectancy': '72.9'}
# {'Year': '1971', 'Country': 'USA', 'Spending_USD': '357.988', 'Life_Expectancy': '71.2'}
# ...
